# %%
import os
import keras
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import matplotlib.patches as patches

from PIL import Image
import PIL

import shutil
from shutil import unpack_archive
from subprocess import check_output

from collections import OrderedDict

# %%
lfw_allnames = pd.read_csv("../dataset/lfw_allnames.csv")
matchpairsDevTest = pd.read_csv("../dataset/matchpairsDevTest.csv")
matchpairsDevTrain = pd.read_csv("../dataset/matchpairsDevTrain.csv")
mismatchpairsDevTest = pd.read_csv("../dataset/mismatchpairsDevTest.csv")
mismatchpairsDevTrain = pd.read_csv("../dataset/mismatchpairsDevTrain.csv")
pairs = pd.read_csv("../dataset/pairs.csv")

# tidy pairs data: 
pairs = pairs.rename(columns ={'name': 'name1', 'Unnamed: 3': 'name2'})
matched_pairs = pairs[pairs["name2"].isnull()].drop("name2",axis=1)
mismatched_pairs = pairs[pairs["name2"].notnull()]
people = pd.read_csv("../dataset/people.csv")

# remove null values
people = people[people.name.notnull()]
peopleDevTest = pd.read_csv("../dataset/peopleDevTest.csv")
peopleDevTrain = pd.read_csv("../dataset/peopleDevTrain.csv")

# %%
# shape data frame so there is a row per image, matched to relevant jpg file
image_paths = lfw_allnames.loc[lfw_allnames.index.repeat(lfw_allnames['images'])]
image_paths['image_path'] = 1 + image_paths.groupby('name').cumcount()
image_paths['image_path'] = image_paths.image_path.apply(lambda x: '{0:0>4}'.format(x))
image_paths['image_path'] = image_paths.name + "/" + image_paths.name + "_" + image_paths.image_path + ".jpg"
image_paths = image_paths.drop("images",axis=1)

# take a random sample: 80% of the data for the test set
lfw_train, lfw_test = train_test_split(image_paths, test_size=0.2)
lfw_train = lfw_train.reset_index().drop("index",axis=1)
lfw_test = lfw_test.reset_index().drop("index",axis=1)

# verify that there is a mix of seen and unseen individuals in the test set
print(len(set(lfw_train.name).intersection(set(lfw_test.name))))
print(len(set(lfw_test.name) - set(lfw_train.name)))
# Out:
# 872
# 867

# %%
image_paths['name'].value_counts()[:10].plot(kind = "bar")
# Out:
# <AxesSubplot: >

# %%
ind_counts = image_paths.groupby('name').count().image_path
print(str(sum(ind_counts[ind_counts==1])) + " individuals, which is " + str(round(100*(sum(ind_counts[ind_counts==1])/sum(ind_counts)))) + "% of the total individuals considered, are only represented by a single image in this dataset.")
# Out:
# 4069 individuals, which is 31% of the total individuals considered, are only represented by a single image in this dataset.

# %%
im = Image.open("../dataset/lfw-deepfunneled/" + str(lfw_train.image_path[0]))
plt.imshow(im)

# %%
not_george = image_paths[image_paths.name!="George_W_Bush"].sample(530)
not_george.name = "not_George"
GWB_data = pd.concat([image_paths[image_paths.name=="George_W_Bush"],
                     not_george])

# %%
# withhold final test data
bush_train, bush_test = train_test_split(GWB_data, test_size=0.2)
#  It is also useful to reserve a validation set in the training data, for use in the model construction
bush_train, bush_val = train_test_split(bush_train,test_size=0.2)

# %%
# initialize sequential network
from keras.models import Sequential
# include convolutional layers
from keras.layers import Conv2D
# Pooling layers
from keras.layers import MaxPooling2D
# flatten layers into single vector
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator

# %%
# use sequential classifier - standard CNN implementation with straightforward single input
Bush_classifier = Sequential()
# We then add layers of complexity to this classifier. The first layer we add is a 2D convolutional layer (as 
# explained above); we pass over the image with a 3x3 window and expect 250*250 pixel input.
# The activation function to introduce non-linearity  is 'relu': Rectified Linear Units, a simple activation function 
# with low computational speeds. One potential downside is that ReLU can lead to "dying neurons", where a neuron is 
# attributed zero influence on classification and gets stuck in this state; we can see output where many neurons have 
# zero influence on the model. If this behaviour manifested in further analysis, an alternate activation function e.g. 
# 'leaky ReLU' would be worth exploring as an alternative
Bush_classifier.add(Conv2D(32, (3, 3), input_shape = (250, 250, 3), activation = 'relu'))

# We now add the pooling layer to reduce the dimension
Bush_classifier.add(MaxPooling2D(pool_size = (2, 2)))

# The next step is to flatten the data, reducing the feature maps to a 1D array
Bush_classifier.add(Flatten())

# We then add a fully connected layer - traditional Multi Layer Perceptron
Bush_classifier.add(Dense(units = 128, activation = 'relu'))

# as we are just training on 'Bush' vs 'non-Bush', we only need to add one classification unit
Bush_classifier.add(Dense(units = 1, activation = 'sigmoid'))

# We are now ready to compile the model. It is possible, and advisable, to introduce more layers to the network, but
# as this model is exploratory we are keeping things straightforward for now (this would change in future iterations)
Bush_classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
def directory_mover(data,dir_name):
    co = 0
    for image in data.image_path:
        # create top directory
        if not os.path.exists(os.path.join('../dataset/output/',dir_name)):
            shutil.os.mkdir(os.path.join('../dataset/output/',dir_name))
        
        data_type = data[data['image_path'] == image]['name']
        data_type = str(list(data_type)[0])
        if not os.path.exists(os.path.join('../dataset/output/',dir_name,data_type)):
            shutil.os.mkdir(os.path.join('../dataset/output/',dir_name,data_type))
        path_from = os.path.join('../dataset/lfw-deepfunneled/',image)
        path_to = os.path.join('../dataset/output/',dir_name,data_type)
        # print(path_to)
        shutil.copy(path_from, path_to)
        # print('Moved {} to {}'.format(image,path_to))
        co += 1
        
    print('Moved {} images to {} folder.'.format(co,dir_name))

# %%
print(os.path.join('../dataset/output/',"Bush_train/"))
# Out:
# ../dataset/output/Bush_train/

# %%
# move images:
directory_mover(bush_train,"Bush_train/")
directory_mover(bush_val,"Bush_val/")
directory_mover(bush_test,"Bush_test/")
# Out:
# Moved 678 images to Bush_train/ folder.
# Moved 170 images to Bush_val/ folder.
# Moved 212 images to Bush_test/ folder.

# %%
train_datagen = keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
shear_range = 0.2,
zoom_range = 0.2,
horizontal_flip = True)
test_datagen = keras.preprocessing.image.ImageDataGenerator(rescale = 1./255)
Bush_training_set = train_datagen.flow_from_directory('../dataset/output/Bush_train/',
                                                 target_size = (250, 250),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
Bush_val_set = test_datagen.flow_from_directory('../dataset/output/Bush_val/',
                                            target_size = (250, 250),
                                            batch_size = 32,
                                            class_mode = 'binary')
Bush_test_set = test_datagen.flow_from_directory('../dataset/output/Bush_test/',
                                            target_size = (250, 250),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 1147 images belonging to 2 classes.
# Found 329 images belonging to 2 classes.
# Found 407 images belonging to 2 classes.

# %%
Bush_history = Bush_classifier.fit_generator(Bush_training_set,
                                             # set steps per epoch equal to the number of training images
                                             steps_per_epoch = 678,
                                             # there is a six hour runtime limit on Kaggle Kernels, restricting the maximum epoch number
                                             epochs = 8,
                                             validation_data = Bush_val_set,
                                             validation_steps = 100)
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_9212\1229753785.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   Bush_history = Bush_classifier.fit_generator(Bush_training_set,
# Epoch 1/8
#  36/678 [>.............................] - ETA: 14:06 - loss: 5.4324 - accuracy: 0.5405WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 5424 batches). You may need to use the repeat() function when building your dataset.
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 100 batches). You may need to use the repeat() function when building your dataset.
# 678/678 [==============================] - 54s 77ms/step - loss: 5.4324 - accuracy: 0.5405 - val_loss: 0.7580 - val_accuracy: 0.4954

# %%
plt.plot(Bush_history.history['accuracy'])
plt.plot(Bush_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(Bush_history.history['loss'])
plt.plot(Bush_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from keras_preprocessing import image

# create a function to predict class of images in a directory, given a trained classifier
def predictions(dir_name,classifier,binary):
    # dir_name should include name of predicted invididual - could edit this to iterate through folders in future
    predictions = []
    for im in os.listdir(dir_name):
        test_image = image.load_img(dir_name + str(im), target_size = (250,250))
        test_image = image.img_to_array(test_image)
        test_image = np.expand_dims(test_image, axis = 0)
        if(binary is True):
            result = float(str(classifier.predict(test_image))[2])
        else: 
            result = np.argmax(classifier.predict(test_image))
        predictions.append(result)
    return(predictions)

# %%
# classes are passed through the algorithm in a random order - we want to retrieve the order of the classes
Bush_test_names = []
# collect all file names
for i in range(len(Bush_test_set.filenames)):
    Bush_test_names.append(Bush_test_set.filenames[i])
# extract unique names, in order
for i in range(len(Bush_test_names)):
    Bush_test_names[i] = Bush_test_names[i].split("/")[0]
Bush_test_name_order = list(OrderedDict.fromkeys(Bush_test_names))
for i in range(len(Bush_test_name_order)):
    Bush_test_name_order[i] = Bush_test_name_order[i].replace("\\","/")

# %%
Bush_test_name_order
# Out:
# ['George_W_Bush/George_W_Bush_0002.jpg',
#  'George_W_Bush/George_W_Bush_0003.jpg',
#  'George_W_Bush/George_W_Bush_0008.jpg',
#  'George_W_Bush/George_W_Bush_0013.jpg',
#  'George_W_Bush/George_W_Bush_0019.jpg',
#  'George_W_Bush/George_W_Bush_0023.jpg',
#  'George_W_Bush/George_W_Bush_0024.jpg',
#  'George_W_Bush/George_W_Bush_0027.jpg',
#  'George_W_Bush/George_W_Bush_0029.jpg',
#  'George_W_Bush/George_W_Bush_0032.jpg',
#  'George_W_Bush/George_W_Bush_0033.jpg',
#  'George_W_Bush/George_W_Bush_0034.jpg',
#  'George_W_Bush/George_W_Bush_0036.jpg',
#  'George_W_Bush/George_W_Bush_0040.jpg',
#  'George_W_Bush/George_W_Bush_0044.jpg',
#  'George_W_Bush/George_W_Bush_0051.jpg',
#  'George_W_Bush/George_W_Bush_0052.jpg',
#  'George_W_Bush/George_W_Bush_0056.jpg',
#  'George_W_Bush/George_W_Bush_0057.jpg',
#  'George_W_Bush/George_W_Bush_0061.jpg',
#  'George_W_Bush/George_W_Bush_0065.jpg',
#  'George_W_Bush/George_W_Bush_0067.jpg',
#  'George_W_Bush/George_W_Bush_0070.jpg',
#  'George_W_Bush/George_W_Bush_0072.jpg',
#  'George_W_Bush/George_W_Bush_0073.jpg',
#  'George_W_Bush/George_W_Bush_0074.jpg',
#  'George_W_Bush/George_W_Bush_0076.jpg',
#  'not_George/Andy_Wisecarver_0001.jpg',
#  'not_George/Anna_Kournikova_0001.jpg',
#  'not_George/Anna_Kournikova_0006.jpg',
#  'not_George/Anthony_LaPaglia_0002.jpg',
#  'not_George/Arnoldo_Aleman_0001.jpg',
#  'not_George/Atal_Bihari_Vajpayee_0007.jpg',
#  'not_George/Barbara_Roberts_0001.jpg',
#  'not_George/Benazir_Bhutto_0003.jpg',
#  'not_George/Betsy_Smith_0001.jpg',
#  'not_George/Bill_Frist_0007.jpg',
#  'not_George/Bill_Graham_0005.jpg',
#  'not_George/Bob_Ferguson_0001.jpg',
#  'not_George/Bobby_Goldwater_0002.jpg',
#  'not_George/Boris_Berezovsky_0001.jpg',
#  'not_George/Brett_Hull_0001.jpg',
#  'not_George/Bryce_Carmine_0001.jpg',
#  'not_George/Carlton_Dotson_0001.jpg',
#  'not_George/Celine_Dion_0002.jpg',
#  'not_George/Charles_Moose_0011.jpg',
#  'not_George/Charlie_Coles_0001.jpg',
#  'not_George/Cherie_Blair_0003.jpg',
#  'not_George/Chung_Mong-joon_0001.jpg',
#  'not_George/Claudia_Schiffer_0002.jpg',
#  'not_George/Clint_Lamebear_0001.jpg',
#  'not_George/Colin_Powell_0141.jpg',
#  'not_George/Colin_Powell_0202.jpg',
#  'not_George/David_Rivkin_Jr_0001.jpg',
#  'not_George/Debbie_Reynolds_0001.jpg',
#  'not_George/Denzel_Washington_0002.jpg',
#  'not_George/Denzel_Washington_0003.jpg',
#  'not_George/Derek_Jeter_0003.jpg',
#  'not_George/Dexter_Jackson_0001.jpg',
#  'not_George/Dominic_Monaghan_0001.jpg',
#  'not_George/Donald_Rumsfeld_0003.jpg',
#  'not_George/Donald_Rumsfeld_0016.jpg',
#  'not_George/Donald_Rumsfeld_0023.jpg',
#  'not_George/Donald_Rumsfeld_0049.jpg',
#  'not_George/Donald_Rumsfeld_0078.jpg',
#  'not_George/Doug_Moe_0001.jpg',
#  'not_George/Edouard_Michelin_0001.jpg',
#  'not_George/Eduardo_Duhalde_0002.jpg',
#  'not_George/El_Hadji_Diouf_0001.jpg',
#  'not_George/Ellen_DeGeneres_0001.jpg',
#  'not_George/Eric_Lloyd_0001.jpg',
#  'not_George/Eric_Rosser_0001.jpg',
#  'not_George/Eve_Pelletier_0001.jpg',
#  'not_George/Evgeni_Plushenko_0001.jpg',
#  'not_George/Francis_Crick_0001.jpg',
#  'not_George/Francis_Ford_Coppola_0002.jpg',
#  'not_George/Gao_Qiang_0002.jpg',
#  'not_George/Gary_Gitnick_0001.jpg',
#  'not_George/Gen_Meredith_0001.jpg',
#  'not_George/George_Maxwell_Richards_0001.jpg',
#  'not_George/Gerald_Fitch_0001.jpg',
#  'not_George/Gerhard_Schroeder_0026.jpg',
#  'not_George/Gerry_Adams_0003.jpg',
#  'not_George/Gray_Davis_0010.jpg',
#  'not_George/Gregory_Geoffroy_0001.jpg',
#  'not_George/Guillermo_Coria_0027.jpg',
#  'not_George/Heidi_Fleiss_0003.jpg',
#  'not_George/Heinz_Feldmann_0001.jpg',
#  'not_George/Hernan_Diaz_0001.jpg',
#  'not_George/Holly_Hunter_0005.jpg',
#  'not_George/Hu_Jintao_0009.jpg',
#  'not_George/Hugh_Grant_0003.jpg',
#  'not_George/Hugo_Chavez_0006.jpg',
#  'not_George/Hugo_Chavez_0040.jpg',
#  'not_George/Humberto_Espinoza_0001.jpg',
#  'not_George/Jacqueline_Gold_0001.jpg',
#  'not_George/James_Blake_0014.jpg',
#  'not_George/James_Ivory_0002.jpg',
#  'not_George/James_Morris_0002.jpg',
#  'not_George/Jaymon_Crabb_0001.jpg',
#  'not_George/Jean-Claude_Braquet_0001.jpg',
#  'not_George/Jennifer_Aniston_0002.jpg',
#  'not_George/Jeremy_Greenstock_0002.jpg',
#  'not_George/Jeremy_Greenstock_0019.jpg',
#  'not_George/Jerry_Falwell_0001.jpg',
#  'not_George/Jim_Tressel_0003.jpg',
#  'not_George/Jimmy_Kimmel_0001.jpg',
#  'not_George/Joan_Laporta_0002.jpg',
#  'not_George/John_Allen_Muhammad_0008.jpg',
#  'not_George/John_Ashcroft_0025.jpg',
#  'not_George/John_Ashcroft_0044.jpg',
#  'not_George/John_Cusack_0001.jpg',
#  'not_George/John_Daly_Jr_0001.jpg',
#  'not_George/John_Howard_0018.jpg',
#  'not_George/John_Manley_0005.jpg',
#  'not_George/John_Negroponte_0016.jpg',
#  'not_George/John_Petty_0001.jpg',
#  'not_George/John_Snow_0017.jpg',
#  'not_George/John_Williams_0001.jpg',
#  'not_George/Johnson_Panjaitan_0001.jpg',
#  'not_George/Jong_Thae_Hwa_0001.jpg',
#  'not_George/Juan_Carlos_Morales_0001.jpg',
#  'not_George/Julianne_Moore_0007.jpg',
#  'not_George/Jung_Bong_0001.jpg',
#  'not_George/Junichi_Inamoto_0001.jpg',
#  'not_George/Justine_Pasek_0007.jpg',
#  'not_George/Katalin_Kollat_0001.jpg',
#  'not_George/Kathleen_Kennedy_Townsend_0001.jpg',
#  'not_George/Katie_Wagner_0001.jpg',
#  'not_George/Keith_Lockhart_0001.jpg',
#  'not_George/Kifah_Ajouri_0001.jpg',
#  'not_George/Lance_Armstrong_0006.jpg',
#  'not_George/Laura_Bush_0034.jpg',
#  'not_George/Leonid_Kuchma_0002.jpg',
#  'not_George/Leslie_Caldwell_0001.jpg',
#  'not_George/Li_Peng_0004.jpg',
#  'not_George/Lisa_Gottsegen_0001.jpg',
#  'not_George/Lisa_Marie_Presley_0002.jpg',
#  'not_George/Lisa_Raymond_0001.jpg',
#  'not_George/Lleyton_Hewitt_0010.jpg',
#  'not_George/Lleyton_Hewitt_0021.jpg',
#  'not_George/Lloyd_Ward_0001.jpg',
#  'not_George/Luis_Figo_0004.jpg',
#  'not_George/Luis_Gonzalez_Macchi_0004.jpg',
#  'not_George/Magui_Serna_0001.jpg',
#  'not_George/Mahima_Chaudhari_0001.jpg',
#  'not_George/Malcolm_Wild_0001.jpg',
#  'not_George/Marc_Grossman_0004.jpg',
#  'not_George/Mark_Geragos_0002.jpg',
#  'not_George/Mark_Heller_0001.jpg',
#  'not_George/Mark_Hurlbert_0004.jpg',
#  'not_George/Mark_Podlesny_0001.jpg',
#  'not_George/Martin_Howard_0001.jpg',
#  'not_George/Martin_Kristof_0001.jpg',
#  'not_George/Martin_McGuinness_0002.jpg',
#  'not_George/Mary_Lou_Retton_0001.jpg',
#  'not_George/Matt_Dillon_0002.jpg',
#  'not_George/Megawati_Sukarnoputri_0017.jpg',
#  'not_George/Michael_Bloomberg_0014.jpg',
#  'not_George/Michelle_Yeoh_0003.jpg',
#  'not_George/Miguel_Contreras_0001.jpg',
#  'not_George/Mike_Babcock_0002.jpg',
#  'not_George/Mike_Miller_0002.jpg',
#  'not_George/Moby_0001.jpg',
#  'not_George/Mohammed_Al_Hindi_0001.jpg',
#  'not_George/Monica_Seles_0002.jpg',
#  'not_George/Muammar_Gaddafi_0001.jpg',
#  'not_George/Mukesh_Ambani_0001.jpg',
#  'not_George/Naji_Sabri_0004.jpg',
#  'not_George/Nancy_Pelosi_0009.jpg',
#  'not_George/Nebojsa_Pavkovic_0001.jpg',
#  'not_George/Nina_Pecari_0001.jpg',
#  'not_George/Norah_Jones_0008.jpg',
#  'not_George/Patricia_Heaton_0002.jpg',
#  'not_George/Paul_Bettany_0001.jpg',
#  'not_George/Paul_Gannon_0001.jpg',
#  'not_George/Paul_Patton_0001.jpg',
#  'not_George/Pervez_Musharraf_0017.jpg',
#  'not_George/Pete_Sampras_0021.jpg',
#  'not_George/Peter_Arnett_0001.jpg',
#  'not_George/Queen_Elizabeth_II_0008.jpg',
#  'not_George/Rafeeuddin_Ahmed_0001.jpg',
#  'not_George/Rahul_Dravid_0001.jpg',
#  'not_George/Recep_Tayyip_Erdogan_0002.jpg',
#  'not_George/Ricardo_Maduro_0001.jpg',
#  'not_George/Rodolfo_Abalos_0001.jpg',
#  'not_George/Roh_Moo-hyun_0015.jpg',
#  'not_George/Romario_Farias_0001.jpg',
#  'not_George/Ron_Dittemore_0003.jpg',
#  'not_George/Ronald_Reagan_0001.jpg',
#  'not_George/Roy_Moore_0003.jpg',
#  'not_George/Russell_Simmons_0003.jpg',
#  'not_George/Saadi_Gadhafi_0001.jpg',
#  'not_George/Saddam_Hussein_0016.jpg',
#  'not_George/Sally_Field_0003.jpg',
#  'not_George/Sandra_Day_OConner_0001.jpg',
#  'not_George/Sean_Penn_0003.jpg',
#  'not_George/Serena_Williams_0045.jpg',
#  'not_George/Sharon_Davis_0001.jpg',
#  'not_George/Shaun_Rusling_0001.jpg',
#  'not_George/Sim_Yong_0001.jpg',
#  'not_George/Soenarno_0001.jpg',
#  'not_George/Stan_Heath_0001.jpg',
#  'not_George/Steve_Fehr_0001.jpg',
#  'not_George/Suzie_McConnell_Serio_0001.jpg',
#  'not_George/Tatiana_Panova_0001.jpg',
#  'not_George/Taylor_Twellman_0001.jpg',
#  'not_George/Teresa_Heinz_Kerry_0001.jpg',
#  'not_George/Terry_Stotts_0001.jpg',
#  'not_George/Teruaki_Masumoto_0001.jpg',
#  'not_George/Thomas_Rupprath_0003.jpg',
#  'not_George/Tiger_Woods_0021.jpg',
#  'not_George/Tim_Salmon_0001.jpg',
#  'not_George/Tirunesh_Dibaba_0001.jpg',
#  'not_George/Toby_Keith_0001.jpg',
#  'not_George/Tom_Brady_0002.jpg',
#  'not_George/Tom_Koenigs_0001.jpg',
#  'not_George/Tomoko_Hagiwara_0001.jpg',
#  'not_George/Tony_Blair_0015.jpg',
#  'not_George/Tony_Blair_0030.jpg',
#  'not_George/Tony_Blair_0039.jpg',
#  'not_George/Tony_Blair_0052.jpg',
#  'not_George/Tony_Stewart_0003.jpg',
#  'not_George/Vanessa_Redgrave_0004.jpg',
#  'not_George/Vladimir_Putin_0028.jpg',
#  'not_George/Wang_Hailan_0001.jpg',
#  'not_George/William_Ford_Jr_0007.jpg',
#  'not_George/Xavier_Malisse_0005.jpg',
#  'not_George/Yoriko_Kawaguchi_0012.jpg',
#  'not_George/Zhu_Rongji_0008.jpg']

# %%
print("../dataset/output/Bush_test/"+ Bush_test_name_order[0]+ "/")
# Out:
# ../dataset/output/Bush_test/George_W_Bush/George_W_Bush_0002.jpg/

# %%
# Compute predictions
Bush_predictions_0 = predictions("../dataset/output/Bush_test/George_W_Bush/",Bush_classifier,binary = True)
Bush_predictions_1 = predictions("../dataset/output/Bush_test/George_W_Bush/",Bush_classifier, binary = True)

# Compare predictions to actual classes
Bush_predictions_frame = pd.DataFrame(list(zip(Bush_predictions_0 + Bush_predictions_1,
                                                [0] * len(Bush_predictions_0) + [1] * len(Bush_predictions_1))),
                                       columns = ['Predictions','Actual'])
# Out:
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step

# %%
Bush_predictions_frame
# Out:
#      Predictions  Actual
# 0            1.0       0
# 1            1.0       0
# 2            1.0       0
# 3            1.0       0
# 4            1.0       0
# ..           ...     ...
# 379          1.0       1
# 380          1.0       1
# 381          1.0       1
# 382          1.0       1
# 383          1.0       1
#
# [384 rows x 2 columns]

# %%
# function for finding the precision and recall of predictions, for any number of predictive classes
def prec_acc(predictions_frame):
    precision = []
    accuracy = []
    recall = []
    for i in range(len(set(predictions_frame.Predictions))):
        tp = predictions_frame[np.logical_and(predictions_frame['Actual'] == i, predictions_frame['Predictions'] == i)].shape[0]
        tn = predictions_frame[np.logical_and(predictions_frame['Actual'] != i, predictions_frame['Predictions'] != i)].shape[0]
        fp = predictions_frame[np.logical_and(predictions_frame['Actual'] != i, predictions_frame['Predictions'] == i)].shape[0]
        fn = predictions_frame[np.logical_and(predictions_frame['Actual'] == i, predictions_frame['Predictions'] != i)].shape[0]
        print(tp)
        print(tn)
        print(fp)
        print(fn)
        total_preds = predictions_frame.shape[0]
        precision.append(tp/(tp + fp))
        accuracy.append((tp + tn)/total_preds)
        recall.append(tp/(tp + fn))
    return(accuracy,precision,recall)

# %%
Bush_accuracy = prec_acc(Bush_predictions_frame)
print('Precision:' + str(Bush_accuracy[1]))
print('Recall:' + str(Bush_accuracy[2]))
print(Bush_test_name_order)
# Out:
# 0
# 192
# 0
# 192
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [72], line 1
# ----> 1 Bush_accuracy = prec_acc(Bush_predictions_frame)
#       2 print('Precision:' + str(Bush_accuracy[1]))
#       3 print('Recall:' + str(Bush_accuracy[2]))
#
# Cell In [71], line 16, in prec_acc(predictions_frame)
#      14 print(fn)
#      15 total_preds = predictions_frame.shape[0]
# ---> 16 precision.append(tp/(tp + fp))
#      17 accuracy.append((tp + tn)/total_preds)
#      18 recall.append(tp/(tp + fn))
#
# ZeroDivisionError: division by zero
